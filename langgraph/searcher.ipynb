# %%
from langchain_core.runnables import RunnableConfig

from langgraph.checkpoint.memory import MemorySaver     
from langgraph.types import Send                        
from langchain.agents import create_agent               
from tavily import TavilyClient
from dotenv import load_dotenv
import os
from pprint import pprint
load_dotenv()

# %%
tavily_api_key = os.environ.get("TAVILY_API_KEY")
tavily_client = TavilyClient(api_key=tavily_api_key)
response = tavily_client.search("Who is Leo Messi?")
pprint(response)

# %%
def serach_node(state: ChatState):
    """Seraches the internet for a relevant information"""

# %%
from googleapiclient.discovery import build

# %%
load_dotenv()
youtube_api_key = os.environ.get("YOUTUBE_API_KEY")
youtube_api_key
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 load_dotenv()
#       2 youtube_api_key = os.environ.get("YOUTUBE_API_KEY")
#       3 youtube_api_key
#
# NameError: name 'load_dotenv' is not defined

# %%
def searchByKeyword():
  results = YouTube.Search.list('id,snippet', {q: 'dogs', maxResults: 25});

  for(var i in results.items) {
    var item = results.items[i];
    Logger.log('[%s] Title: %s', item.id.videoId, item.snippet.title);
  }
}

# %%
touch youtube-searcher/state.py youtube-searcher/nodes.py youtube-searcher/tools.py youtube-searcher/graph.py youtube-searcher/prompts.py youtube-searcher/config.py main.py


